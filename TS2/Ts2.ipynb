# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Procesamiento Digital de Señales
#
# # Trabajo Práctico Nº2
# #### Alumno:    Fernando Daniel Fiamberti

# %% [markdown]
# # <span style="color:Blue">Introducción</span>
#
# Mediante el generador de señales senoidales configurable realizado en la tarea anterior,
# se debe graficar la DFT de la señal generada.
#
#
#
#
# # Desarrollo de la tarea
#
# ### <span style="color:Blue">Código implementado:</span>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Función que genera una señal senoidal a partir de los parámetros recibidos,
calcula la DFT y luego la grafica junto con la señal generada.


Created on Mon Aug 26 19:27:10 2025

@author: Fernando Daniel Fiamberti
"""
import numpy as np
import matplotlib.pyplot as plt



"""
Parámetros de la señal senoidal:

      ax:     Amplitud máxima de la señal [V]
      
      dc:     Valor medio de la señal [V]
      
      fx:     Frecuencia de la señal [Hz]
      
      ph:     Fase de la señal [rad]
      
      N :     Número de muestras
      
      fs:     Frecuencia de muestreo del ADC [Hz]
      
      Ts:     Período de muestreo [s]       
      
      T_sim:  Tiempo que dura la simulación [s]


Devuelve:

      tt : Tiempo correspondiente a cada muestra
      
      xx : Señal senoidal generada
""" 





"""
Parámetros de la DFT:

       x: Señal muestreada 

Devuelve:
      
      X : DFT de la señal
""" 




# Función que genera una señal senoidal con los parámetros especificados:
def generador_senoidal(ax, dc, fx, ph, N, fs):
 
    # Genera el vector de tiempo
    tt = np.arange(start = 0, stop = T_sim, step = Ts)

    
    # Crea la señal senoidal
    xx = ax * np.sin(2 * np.pi * fx * tt + ph) + dc
    
    return tt, xx




# Función para calcular la DFT manualmente
def dft(x):
    N = len(x)
    X = np.zeros(N, dtype=complex)  # Array para los coeficientes de frecuencia
    for k in range(N):
        # Cálculo de la DFT en el índice k
        X[k] = np.sum(x * np.exp(-2j * np.pi * k * np.arange(N) / N))
    return X







# Parámetros de la señal
ax = 2                # Amplitud    [v]
dc = 0                # Valor medio [v]
fx = 1                # Frecuencia  [Hz]
ph = 0                # Fase        [rad]


# Parámetros de muestreo
fs = 100              # Frec. de muestreo    [Hz]
N = fs                # Número de muestras
Ts = 1/fs             # Período de muestreo  [s]
T_sim = N * Ts        # Tiempo de simulación [s]




# Llamo a la función para generar la senoidal muestreada
tt, xx = generador_senoidal(ax, dc, fx, ph, N, fs)

# Calcula la DFT de la señal
X = dft(xx)


# Toma solo la mitad positiva del espectro
half_N = N // 2                  # Solo tomo hasta la mitad de las frecuencias
X_pos = X[:half_N]               # Coeficientes del espectro positivo
magnitudes = np.abs(X_pos)       # Magnitud 

# Eje de frecuencias [muestras] (es un entero)
frequencias = np.arange(half_N)  # Eje de frecuencias



"""
plt.subplot(filas, columnas, ìndice)

    filas:    Número de filas

    columnas: Número de columnas

    ìndice: Índice del gráfico donde se debe colocar el gráfico actual 
            (los índices empiezan desde 1).
"""


# Grafica la señal generada
plt.subplot(1, 2, 1)
plt.plot( tt, xx, 'o--')
plt.title('Senoidal Generada')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [V]')
plt.grid(True)
plt.show()


# Grafica la magnitud de la DFT (solo espectro positivo)
plt.subplot(1, 2, 2)
# plt.figure(figsize=(10, 6))
plt.scatter(frequencias , magnitudes, color='g')  # Usamos scatter para no conectar los puntos
plt.title("Espectro (DFT)")
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("Magnitud")
plt.grid(True)
plt.show()


"""
# %matplotlib qt  +   ENTER     =>

permite graficar en una pantalla emergente
"""
# Out:
# '\n%matplotlib qt  +   ENTER     =>\n\npermite graficar en una pantalla emergente\n'

# %% [markdown]
# # <span style="color:Blue">Análisis del código escrito en Python y ejecutado en Spyder 5</span>
#
# ### A continuación se explicará el código paso a paso:

# %% [markdown]
# Encabezado:

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# %% [markdown]
# **(#!):** Indica que este archivo debe ejecutarse utilizando el intérprete de **Python 3** disponible en el entorno.
#
# En Linux permite ejecutar el archivo directamente **como un script (./script.py)** sin escribir python3 script.py.

# %%
"""
Función que genera una señal senoidal a partir de los parámetros recibidos,
calcula la DFT y luego la grafica junto con la señal generada.


Created on Mon Aug 26 19:27:10 2025

@author: Fernando Daniel Fiamberti
"""
# Out:
# '\nFunción que genera una señal senoidal a partir de los parámetros recibidos,\ncalcula la DFT y luego la grafica junto con la señal generada.\n\n\nCreated on Mon Aug 26 19:27:10 2025\n\n@author: Fernando Daniel Fiamberti\n'

# %% [markdown]
# **Comentario:**
#
# Este párrafo contiene el motivo del código, la fecha en la que fue creado y el autor.
#
# **("""):** tres comillas indican el **inicio** o el **cierre** de un comentario realizado como **párrafo**. El párrafo de comentario debe **iniciarse** con **comillas triples**  y **cerrarse** también con **comillas triples**.

# %%
import numpy as np

# %% [markdown]
# **numpy** es una **biblioteca de Python** utilizada para trabajar con matrices, vectores, números, y realizar cálculos matemáticos de manera **muy eficiente**.**Se importa como np** para **escribir menos** cada vez que se usa. En lugar de escribir numpy.array(...), **solo escribo np.array(...)**.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **matplotlib.pyplot** es un **módulo de la biblioteca matplotlib**, utilizado para **crear gráficos**. Se **importa como plt** por
# convención, para **escribir menos**. En lugar de matplotlib.pyplot.plot(...), **escribo plt.plot(...)**.

# %%
"""
Parámetros de la señal senoidal:

      ax:     Amplitud máxima de la señal [V]
      
      dc:     Valor medio de la señal [V]
      
      fx:     Frecuencia de la señal [Hz]
      
      ph:     Fase de la señal [rad]
      
      N :     Número de muestras
      
      fs:     Frecuencia de muestreo del ADC [Hz]
      
      Ts:     Período de muestreo [s]       
      
      T_sim:  Tiempo que dura la simulación [s]


Devuelve:

      tt : Tiempo correspondiente a cada muestra
      
      xx : Señal senoidal generada
""" 





"""
Parámetros de la DFT:

       x: Señal muestreada 

Devuelve:
      
      X : DFT de la señal
"""
# Out:
# '\nParámetros de la DFT:\n\n       x: Señal muestreada \n\nDevuelve:\n      \n      X : DFT de la señal\n'

# %% [markdown]
# Párrafo que describe los parámetros que recibe la función que genera la señal senoidal.

# %%
# Función que genera una señal senoidal con los parámetros especificados:
def generador_senoidal(ax, dc, fx, ph, N, fs):
 
    # Genera el vector de tiempo
    tt = np.arange(start = 0, stop = T_sim, step = Ts)

    
    # Crea la señal senoidal
    xx = ax * np.sin(2 * np.pi * fx * tt + ph) + dc
    
    return tt, xx

# %% [markdown]
# Define una función en Python llamada generador_senoidal, que **genera la señal senoidal pedida**. Entre paréntesis están
# los parámetros de entrada que necesita la función para realizar los cálculos.**Devuelve el vector de tiempo y la señal senoidal generada**.
# Una **función se define** en **Python** utilizando la **palabra clave def** seguida del nombre de la función, los parámetros entre paréntesis y luego dos puntos. El **bloque de código** que **pertenece a la función** se escribe con **4 espacios a la derecha**, o sea, **indentado con 4 espacios**.

# %%
# Función para calcular la DFT
def dft(x):
    N = len(x)
    X = np.zeros(N, dtype=complex)  # Array para los coeficientes de frecuencia
    for k in range(N):
        # Cálculo de la DFT en el índice k
        X[k] = np.sum(x * np.exp(-2j * np.pi * k * np.arange(N) / N))
    return X

# %%
# Parámetros de la señal
ax = 2                # Amplitud    [v]
dc = 0                # Valor medio [v]
fx = 1                # Frecuencia  [Hz]
ph = 0                # Fase        [rad]


# Parámetros de muestreo
fs = 100              # Frec. de muestreo    [Hz]
N = fs                # Número de muestras
Ts = 1/fs             # Período de muestreo  [s]
T_sim = N * Ts        # Tiempo de simulación [s]

# %% [markdown]
# Se definen los parámetros de la señal senoidal pedida y de la señal que la muestrea.

# %%
# Llamo a la función
tt, xx = generador_senoidal(ax, dc, fx, ph, N, fs)

# %% [markdown]
# Se llama a la función que genera la señal senoidal. El resultado de esta función se **desempaqueta** en **dos variables**:     tt y xx
#
# **xx y tt** son **vectores de Nx1**

# %%
# Calcula la DFT de la señal
X = dft(xx)

# %% [markdown]
# Se llama a la función que calcula la DFT la señal senoidal generada. El resultado de esta función se **desempaqueta** en **una variable**:     X
#
# **X** es **un vector de Nx1**

# %%
# Toma solo la mitad positiva del espectro
half_N = N // 2                  # Solo tomo hasta la mitad de las frecuencias
X_pos = X[:half_N]               # Coeficientes del espectro positivo
magnitudes = np.abs(X_pos)       # Magnitud

# %% [markdown]
# El espectro generado por la DFT se compone de componentes en las frecuencias negativas y en las frecuencias positivas. En estas líneas me quedo solo con las magnitudes la parte positiva del espectro (las frecuencias positivas).

# %%
# Eje de frecuencias [muestras] (es un entero)
frequencias = np.arange(half_N)  # Eje de frecuencias

# %% [markdown]
# Genera un vector con las frecuencias

# %%
"""
plt.subplot(filas, columnas, ìndice)

    filas:    Número de filas

    columnas: Número de columnas

    ìndice: Índice del gráfico donde se debe colocar el gráfico actual 
            (los índices empiezan desde 1).
"""
# Out:
# '\nplt.subplot(filas, columnas, ìndice)\n\n    filas:    Número de filas\n\n    columnas: Número de columnas\n\n    ìndice: Índice del gráfico donde se debe colocar el gráfico actual \n            (los índices empiezan desde 1).\n'

# %% [markdown]
# Comento se utiliza la función subplot para graficar la señal senoidal y su espectro, uno al lado del otro.

# %%
# Grafica la señal generada
plt.subplot(1, 2, 1)
plt.plot( tt, xx, 'o--')
plt.title('Senoidal Generada')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [V]')
plt.grid(True)
plt.show()


# Grafica la magnitud de la DFT (solo espectro positivo)
plt.subplot(1, 2, 2)
# plt.figure(figsize=(10, 6))
plt.scatter(frequencias , magnitudes, color='g')  # Usamos scatter para no conectar los puntos
plt.title("Espectro (DFT)")
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("Magnitud")
plt.grid(True)
plt.show()

# %% [markdown]
# Grafico la señal y su espectro.

# %%
"""
# %matplotlib qt  +   ENTER     =>

permite graficar en una pantalla emergente
"""
# Out:
# '\n%matplotlib qt  +   ENTER     =>\n\npermite graficar en una pantalla emergente\n'

# %% [markdown]
# Con %matplotlib qt   aparece en una pantalla emergente el gràfico de la señal generada y su espectro, uno al lado del otor.
